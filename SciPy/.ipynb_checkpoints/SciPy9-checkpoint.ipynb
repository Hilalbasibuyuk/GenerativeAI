# %%
import numpy as np
import pandas as pd
from scipy.misc import derivative
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**2 * np.sin(2*x) *np.exp(-x)
x = np.linspace(0,1,100)

# %%
plt.plot(x,f(x))
plt.plot(x,derivative(f,x,dx = 1e-6))
plt.plot(x,derivative(f,x,dx = 1e-6,n=2))
# Out:
# C:\Users\hilal\AppData\Local\Temp\ipykernel_14872\1274542495.py:2: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.plot(x,derivative(f,x,dx = 1e-6))
# C:\Users\hilal\AppData\Local\Temp\ipykernel_14872\1274542495.py:3: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.plot(x,derivative(f,x,dx = 1e-6,n=2))

# %% [markdown]
# Integration

# %%
from scipy.integrate import quad
integrand = lambda x: x**2 * np.sin(x) *np.exp(-x)
integral,integral_error = quad(integrand,0,1)

# %%
integral
# Out:
# 0.10246777930717413

# %%
integral_error
# Out:
# 1.1376208786903388e-15

# %%
from scipy.integrate import nquad
# ?nquad
