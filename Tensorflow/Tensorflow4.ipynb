# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df = pd.read_excel("merc.xlsx")
df.head(7)
# Out:
#    year   price transmission  mileage  tax   mpg  engineSize
# 0  2005    5200    Automatic    63000  325  32.1         1.8
# 1  2017   34948    Automatic    27000   20  61.4         2.1
# 2  2016   49948    Automatic     6200  555  28.0         5.5
# 3  2016   61948    Automatic    16000  325  30.4         4.0
# 4  2016   73948    Automatic     4000  325  30.1         4.0
# 5  2011  149948    Automatic     3000  570  21.4         6.2
# 6  2018   30948    Automatic    16000  145  47.9         2.1

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df.isnull().sum() # 0 var mı kontrolü
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize = (7,5))
sbn.distplot(df["price"])
# Out:
# C:\Users\hilal\AppData\Local\Temp\ipykernel_12944\1450211865.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sbn.scatterplot(x = "mileage", y="price", data = df)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
df.sort_values("price",ascending = False).head(20) # En yüksek fiyatlı arabalar
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
df.sort_values("price",ascending = True).head(20) # En düşük fiyatlı arabalar
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(df)
# Out:
# 13119

# %%
len(df)*0.01
# Out:
# 131.19

# %%
yuzdeDoksanDokuzdf = df.sort_values("price",ascending= False).iloc[131:]

# %%
yuzdeDoksanDokuzdf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.displot(yuzdeDoksanDokuzdf["price"])
# Out:
# C:\Users\hilal\anaconda3\envs\Hilal\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.groupby("year").mean(["price"])# Yıllardaki fiyat ortalaması
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
yuzdeDoksanDokuzdf.groupby("year").mean(["price"])
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
df = df[df.year != 1970]

# %%
df.head(10)
# Out:
#    year   price transmission  mileage  tax   mpg  engineSize
# 0  2005    5200    Automatic    63000  325  32.1         1.8
# 1  2017   34948    Automatic    27000   20  61.4         2.1
# 2  2016   49948    Automatic     6200  555  28.0         5.5
# 3  2016   61948    Automatic    16000  325  30.4         4.0
# 4  2016   73948    Automatic     4000  325  30.1         4.0
# 5  2011  149948    Automatic     3000  570  21.4         6.2
# 6  2018   30948    Automatic    16000  145  47.9         2.1
# 7  2012   10948    Automatic   107000  265  36.7         3.5
# 8  2019  139948    Automatic    12000  145  21.4         4.0
# 9  2017   19750    Automatic    15258   30  64.2         2.1

# %%
df = df.drop(["transmission"],axis =1)

# %%
x = df.drop("price",axis = 1)
y = df["price"].values

# %%
x
# Out:
#        year  mileage  tax   mpg  engineSize
# 0      2005    63000  325  32.1         1.8
# 1      2017    27000   20  61.4         2.1
# 2      2016     6200  555  28.0         5.5
# 3      2016    16000  325  30.4         4.0
# 4      2016     4000  325  30.1         4.0
# ...     ...      ...  ...   ...         ...
# 13114  2020      500  145  55.4         2.0
# 13115  2020     2500  145  55.4         2.0
# 13116  2019    11612  145  41.5         2.1
# 13117  2019     2426  145  45.6         2.0
# 13118  2019     2075  145  52.3         2.9
#
# [13118 rows x 5 columns]

# %%
y
# Out:
# array([ 5200, 34948, 49948, ..., 30999, 37990, 54999], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3, random_state = 20)

# %%
len(x_train)
# Out:
# 9182

# %%
len(y_train)
# Out:
# 9182

# %%
len(x_test)
# Out:
# 3936

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9182, 5)

# %%
model = Sequential()

model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))

model.add(Dense(1))
model.compile(optimizer = "adam", loss = "mse")

# %%
model.fit(x = x_train, y = y_train, validation_data = (x_test,y_test), batch_size = 250, epochs = 300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 4s 23ms/step - loss: 746420608.0000 - val_loss: 759205632.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 9ms/step - loss: 746382080.0000 - val_loss: 759141760.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 9ms/step - loss: 746262208.0000 - val_loss: 758928768.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 9ms/step - loss: 745880640.0000 - val_loss: 758272448.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 8ms/step - loss: 744746112.0000 - val_loss: 756374784.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 9ms/step - loss: 741771392.0000 - val_loss: 751801408.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 9ms/step - loss: 735182144.0000 - val_loss: 742265408.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 8ms/step - loss: 722300160.0000 - val_loss: 724526272.0000
# Epoch 9/300
# ...

# %%
kayipVeri = pd.DataFrame(model.history.history)

# %%
kayipVeri.head(10)
# Out:
#           loss     val_loss
# 0  746420608.0  759205632.0
# 1  746382080.0  759141760.0
# 2  746262208.0  758928768.0
# 3  745880640.0  758272448.0
# 4  744746112.0  756374784.0
# 5  741771392.0  751801408.0
# 6  735182144.0  742265408.0
# 7  722300160.0  724526272.0
# 8  699541248.0  694693312.0
# 9  662846464.0  648556352.0

# %%
kayipVeri.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahmin = model.predict(x_test)
# Out:
# 123/123 [==============================] - 1s 3ms/step

# %%
tahmin
# Out:
# array([[25522.602],
#        [34737.973],
#        [10672.895],
#        ...,
#        [26024.945],
#        [28259.8  ],
#        [24423.082]], dtype=float32)

# %%
mean_absolute_error(y_test, tahmin)# 3552 pound bir fark var
# Out:
# 3552.0319166726213

# %%
df.describe() # Ortalama fiyat 24000 civarı ve 3552 fark var ve bu fark çok sorun teşkil etmez
# Out:
#                year          price       mileage           tax           mpg  \
# count  13118.000000   13118.000000   13118.00000  13118.000000  13118.000000
# mean    2017.299893   24698.574020   21950.16504    129.958835     55.157059
# std        2.186129   11843.126668   21177.20571     65.244877     15.220025
# min     1997.000000     650.000000       1.00000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6096.75000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.00000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31781.75000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.00000    580.000000    217.300000
#
#          engineSize
# count  13118.000000
# mean       2.071688
# std        0.572162
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test,tahmin)
plt.plot(y_test,y_test,"g-*")

# %%
df.iloc[2]
# Out:
# year           2016.0
# price         49948.0
# mileage        6200.0
# tax             555.0
# mpg              28.0
# engineSize        5.5
# Name: 2, dtype: float64

# %%
yeniArabaSeries = df.drop("price",axis=1).iloc[2]

# %%
yeniArabaSeries
# Out:
# year          2016.0
# mileage       6200.0
# tax            555.0
# mpg             28.0
# engineSize       5.5
# Name: 2, dtype: float64

# %%
yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))
# Out:
# C:\Users\hilal\anaconda3\envs\Hilal\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
model.predict(yeniArabaSeries)
# Out:
# 1/1 [==============================] - 0s 180ms/step
# array([[57835.09]], dtype=float32)
